# %%
import agents_env
from agents_env.agent_replay_motion import HumanoidReplay
from utils.SimpleConverter import SimpleConverter
from utils.util_data import *

# %%
from datetime import datetime
import functools
from IPython.display import HTML
import jax
from jax import numpy as jp
import numpy as np
from typing import Any, Dict, Sequence, Tuple, Union
from brax import base
from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.envs.base import Env, PipelineEnv, State
from brax.mjx.base import State as MjxState
from brax.training.agents.ppo import train as ppo
from brax.training.agents.ppo import networks as ppo_networks
from brax.io import html, mjcf, model
from etils import epath
from flax import struct
from matplotlib import pyplot as plt
import mediapy as media
from ml_collections import config_dict
import mujoco
from mujoco import mjx
from jax import vmap

# %%
envs.register_environment('humanoidReplay', HumanoidReplay)

# %% [markdown]
# Get the motion data and the model path

# %%
trajectory = SimpleConverter('motions/humanoid3d_punch.txt')
trajectory.load_mocap()
model_path = 'models/final_humanoid.xml'

# %%
data_mocap_matrix = jp.asarray(trajectory.data)
data_pos_mocap = jp.asarray(trajectory.data_pos)
data_vel_mocap = jp.asarray(trajectory.data_vel)

data_dict_mocap = trajectory.duration_dict

# %%
data_dict_mocap
# Out:
# {0: [0.0, 0.0333333015],
#  1: [0.03333330154418945, 0.0333333015],
#  2: [0.0666666030883789, 0.0333333015],
#  3: [0.09999990463256836, 0.0333333015],
#  4: [0.1333332061767578, 0.0333333015],
#  5: [0.16666650772094727, 0.0333333015],
#  6: [0.19999980926513672, 0.0333333015],
#  7: [0.23333311080932617, 0.0333333015],
#  8: [0.2666664123535156, 0.0333333015],
#  9: [0.2999997138977051, 0.0333333015],
#  10: [0.33333301544189453, 0.0333333015],
#  11: [0.366666316986084, 0.0333333015],
#  12: [0.39999961853027344, 0.0333333015],
#  13: [0.4333329200744629, 0.0333333015],
#  14: [0.46666622161865234, 0.0333333015],
#  15: [0.4999995231628418, 0.0333333015],
#  16: [0.5333328247070312, 0.0333333015],
#  17: [0.5666661262512207, 0.0333333015],
#  18: [0.5999994277954102, 0.0333333015],
#  19: [0.6333327293395996, 0.0333333015],
#  20: [0.6666660308837891, 0.0333333015],
#  21: [0.6999993324279785, 0.0333333015],
#  22: [0.733332633972168, 0.0333333015],
#  23: [0.7666659355163574, 0.0333333015],
#  24: [0.7999992370605469, 0.0333333015],
#  25: [0.8333325386047363, 0.0333333015],
#  26: [0.8666658401489258, 0.0333333015],
#  27: [0.8999991416931152, 0.0333333015],
#  28: [0.9333324432373047, 0.0333333015],
#  29: [0.9666657447814941, 0.0333333015],
#  30: [0.9999990463256836, 0.0333333015],
#  31: [1.033332347869873, 0.0333333015],
#  32: [1.0666656494140625, 0.0333333015],
#  33: [1.099998950958252, 0.0333333015],
#  34: [1.1333322525024414, 0.0333333015],
#  35: [1.1666655540466309, 0.0333333015],
#  36: [1.1999988555908203, 0.0333333015],
#  37: [1.2333321571350098, 0.0333333015],
#  38: [1.2666654586791992, 0.0333333015],
#  39: [1.2999987602233887, 0.0333333015],
#  40: [1.3333320617675781, 0.0333333015],
#  41: [1.3666653633117676, 0.0333333015],
#  42: [1.399998664855957, 0.0333333015],
#  43: [1.4333319664001465, 0.0333333015],
#  44: [1.466665267944336, 0.0333333015],
#  45: [1.4999985694885254, 0.0333333015],
#  46: [1.5333318710327148, 0.0333333015],
#  47: [1.5666651725769043, 0.0333333015],
#  48: [1.5999984741210938, 0.0333333015],
#  49: [1.6333317756652832, 0.0333333015],
#  50: [1.6666650772094727, 0.0333333015],
#  51: [1.699998378753662, 0.0333333015],
#  52: [1.7333316802978516, 0.0333333015],
#  53: [1.766664981842041, 0.0333333015],
#  54: [1.7999982833862305, 0.0333333015],
#  55: [1.83333158493042, 0.0333333015],
#  56: [1.8666648864746094, 0.0333333015],
#  57: [1.8999981880187988, 0.0333333015],
#  58: [1.9333314895629883, 0.0333333015],
#  59: [1.9666647911071777, 0.0333333015],
#  60: [1.9999980926513672, 0.0333333015],
#  61: [2.0333313941955566, 0.0333333015],
#  62: [2.066664695739746, 0.0333333015],
#  63: [2.0999979972839355, 0.0333333015],
#  64: [2.133331298828125, 0.0]}

# %%
env_name = 'humanoidReplay'
env = envs.get_environment(env_name=env_name,
                           reference_trajectory_qpos=data_pos_mocap,
                           reference_trajectory_qvel = data_vel_mocap,
                            duration_trajectory=trajectory.total_time,
                            dict_duration= data_dict_mocap,
                           model_path=model_path)
jit_reset = jax.jit(env.reset)
jit_step = jax.jit(env.step)

# %%
env.reference_trajectory_qpos.shape
# Out:
# (65, 35)

# %%
def visualizer(rollout):
    media.show_video(env.render(rollout, camera='back'), fps=1.0/env.dt)

# %%
# initialize the state
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state.pipeline_state]

for k in range(len(env.dict_duration)):
    qpos = state.pipeline_state.qpos
    tmp_pos = env.reference_trajectory_qpos[k]
    updated = qpos.at[:].set(tmp_pos[:])
    
    state = state.tree_replace({'pipeline_state.qpos': updated})
    ctrl = -0.1 * jp.ones(env.sys.nv)
    state = jit_step(state, ctrl)
    #print(state.pipeline_state.time)
    rollout.append(state.pipeline_state)

# %%
visualizer(rollout)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# Visualize only the arm

# %%
chest_x = get_joint_index(env.sys.mj_model,'chest','X')


#data of all the right arm
right_shoulder_x = get_joint_index(env.sys.mj_model,'right_shoulder','X')
right_shoulder_y = get_joint_index(env.sys.mj_model,'right_shoulder','Y')
right_shoulder_z = get_joint_index(env.sys.mj_model,'right_shoulder','Z')

right_elbow = get_joint_index(env.sys.mj_model,'right_elbow','X')


print(chest_x)
print(right_shoulder_x)
print(right_shoulder_y)
print(right_shoulder_z)
print(right_elbow)
# Out:
# 7
# 13
# 14
# 15
# 16

# %%
# initialize the state
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state.pipeline_state]

for k in range(len(env.dict_duration)):
    qpos = state.pipeline_state.qpos
    #only grab the right arm poses
    tmp_pos = env.reference_trajectory_qpos[k,right_shoulder_x:right_elbow+1]
    #gran zeor data, to concatenate
    new_pos = jp.concatenate([jp.zeros(right_shoulder_x)])
    updated = qpos.at[right_shoulder_x:right_elbow+1].set(tmp_pos)
    
    
    state = state.tree_replace({'pipeline_state.qpos': updated})
    ctrl = -0.1 * jp.ones(env.sys.nv)
    state = jit_step(state, ctrl)
    #print(state.pipeline_state.time)
    rollout.append(state.pipeline_state)

# %%
visualizer(rollout)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# Now grab a specific frame, and only render that

# %%
# initialize the state
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state.pipeline_state]
#keep track of the time
time = 0

for k in range(len(env.dict_duration)):
    qpos = state.pipeline_state.qpos
    # print("current-time", time)
    
    #so now on the dictionary grab a frame and see the duration and dt
    timestep_trajectory, dura_dt = env.dict_duration[k]
    if k >= 45:
        
        # print('time step', timestep_trajectory)
        # print('dura', dura_dt)
        # #only grab the right arm poses
        # tmp_pos = data_pos_mocap[k,right_shoulder_x:right_elbow+1]
        # updated = qpos.at[right_shoulder_x:right_elbow+1].set(tmp_pos
        tmp_pos = env.reference_trajectory_qpos[k]
        updated = qpos.at[:].set(tmp_pos[:])
        
        state = state.tree_replace({'pipeline_state.qpos': updated})
        ctrl = -0.1 * jp.ones(env.sys.nv)
    state = jit_step(state, ctrl)
    #print(state.pipeline_state.time)
    rollout.append(state.pipeline_state)
        
    #time += env.sys.dt
    time += trajectory.durations[k]

# %%
visualizer(rollout)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
env.dict_duration
# Out:
# {0: [0.0, 0.0333333015],
#  1: [0.03333330154418945, 0.0333333015],
#  2: [0.0666666030883789, 0.0333333015],
#  3: [0.09999990463256836, 0.0333333015],
#  4: [0.1333332061767578, 0.0333333015],
#  5: [0.16666650772094727, 0.0333333015],
#  6: [0.19999980926513672, 0.0333333015],
#  7: [0.23333311080932617, 0.0333333015],
#  8: [0.2666664123535156, 0.0333333015],
#  9: [0.2999997138977051, 0.0333333015],
#  10: [0.33333301544189453, 0.0333333015],
#  11: [0.366666316986084, 0.0333333015],
#  12: [0.39999961853027344, 0.0333333015],
#  13: [0.4333329200744629, 0.0333333015],
#  14: [0.46666622161865234, 0.0333333015],
#  15: [0.4999995231628418, 0.0333333015],
#  16: [0.5333328247070312, 0.0333333015],
#  17: [0.5666661262512207, 0.0333333015],
#  18: [0.5999994277954102, 0.0333333015],
#  19: [0.6333327293395996, 0.0333333015],
#  20: [0.6666660308837891, 0.0333333015],
#  21: [0.6999993324279785, 0.0333333015],
#  22: [0.733332633972168, 0.0333333015],
#  23: [0.7666659355163574, 0.0333333015],
#  24: [0.7999992370605469, 0.0333333015],
#  25: [0.8333325386047363, 0.0333333015],
#  26: [0.8666658401489258, 0.0333333015],
#  27: [0.8999991416931152, 0.0333333015],
#  28: [0.9333324432373047, 0.0333333015],
#  29: [0.9666657447814941, 0.0333333015],
#  30: [0.9999990463256836, 0.0333333015],
#  31: [1.033332347869873, 0.0333333015],
#  32: [1.0666656494140625, 0.0333333015],
#  33: [1.099998950958252, 0.0333333015],
#  34: [1.1333322525024414, 0.0333333015],
#  35: [1.1666655540466309, 0.0333333015],
#  36: [1.1999988555908203, 0.0333333015],
#  37: [1.2333321571350098, 0.0333333015],
#  38: [1.2666654586791992, 0.0333333015],
#  39: [1.2999987602233887, 0.0333333015],
#  40: [1.3333320617675781, 0.0333333015],
#  41: [1.3666653633117676, 0.0333333015],
#  42: [1.399998664855957, 0.0333333015],
#  43: [1.4333319664001465, 0.0333333015],
#  44: [1.466665267944336, 0.0333333015],
#  45: [1.4999985694885254, 0.0333333015],
#  46: [1.5333318710327148, 0.0333333015],
#  47: [1.5666651725769043, 0.0333333015],
#  48: [1.5999984741210938, 0.0333333015],
#  49: [1.6333317756652832, 0.0333333015],
#  50: [1.6666650772094727, 0.0333333015],
#  51: [1.699998378753662, 0.0333333015],
#  52: [1.7333316802978516, 0.0333333015],
#  53: [1.766664981842041, 0.0333333015],
#  54: [1.7999982833862305, 0.0333333015],
#  55: [1.83333158493042, 0.0333333015],
#  56: [1.8666648864746094, 0.0333333015],
#  57: [1.8999981880187988, 0.0333333015],
#  58: [1.9333314895629883, 0.0333333015],
#  59: [1.9666647911071777, 0.0333333015],
#  60: [1.9999980926513672, 0.0333333015],
#  61: [2.0333313941955566, 0.0333333015],
#  62: [2.066664695739746, 0.0333333015],
#  63: [2.0999979972839355, 0.0333333015],
#  64: [2.133331298828125, 0.0]}

# %%
def visualize_per_time_step():
    # initialize the state
    state = jit_reset(jax.random.PRNGKey(0))
    rollout = [state.pipeline_state]
    time = 0
    frames = 0
    N=1300
    for i in range(N):
        qpos = state.pipeline_state.qpos
        #print("current-time", time)
        frames = np.clip(frames,0,len(env.dict_duration)-1)
        
        #so now on the dictionary grab a frame and see the duration and dt
        timestep_trajectory, dura_dt = env.dict_duration[frames]
        
        if time >= timestep_trajectory:
            #we increment the frames
            frames+=1
            
            # print('time step', timestep_trajectory)
            # print('dura', dura_dt)
        
            # print("frames:", frames)
            # #only grab the right arm poses
            # tmp_pos = data_pos_mocap[k,right_shoulder_x:right_elbow+1]
            # updated = qpos.at[right_shoulder_x:right_elbow+1].set(tmp_pos
            tmp_pos = env.reference_trajectory_qpos[frames]
            updated = qpos.at[:].set(tmp_pos[:])
            
            state = state.tree_replace({'pipeline_state.qpos': updated})
            ctrl = -0.1 * jp.ones(env.sys.nv)
            state = jit_step(state, ctrl)

                    #print(state.pipeline_state.time)
            rollout.append(state.pipeline_state)
            
        time += env.sys.dt
    return rollout

# %%
rollout = visualize_per_time_step()
visualizer(rollout)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# Visualization on other movements

# %%
stand_up = SimpleConverter('motions/humanoid3d_getup_faceup.txt')
stand_up.load_mocap()

# %%
stand_data_mocap_matrix = jp.asarray(stand_up.data)
stand_data_pos_mocap = jp.asarray(stand_up.data_pos)
stand_data_vel_mocap = jp.asarray(stand_up.data_vel)
stand_data_dict_mocap = stand_up.duration_dict

# %%
env.set_new_trajectory(stand_up)

# %%
env.duration_trajectory
# Out:
# 3.7665161581999853

# %%
stand_up.total_time
# Out:
# 3.7665161581999853

# %%
# initialize the state
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state.pipeline_state]

for k in range(len(env.dict_duration)):
    qpos = state.pipeline_state.qpos
    tmp_pos = env.reference_trajectory_qpos[k]
    updated = qpos.at[:].set(tmp_pos[:])
    
    state = state.tree_replace({'pipeline_state.qpos': updated})
    ctrl = -0.1 * jp.ones(env.sys.nv)
    state = jit_step(state, ctrl)
    #print(state.pipeline_state.time)
    rollout.append(state.pipeline_state)

# %%
visualizer(rollout)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
len(env.dict_duration)
# Out:
# 227

# %%
env.reference_trajectory_qpos.shape
# Out:
# (227, 35)

# %%
# initialize the state
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state.pipeline_state]
#keep track of the time
time = 0

for k in range(len(env.dict_duration)):
    qpos = state.pipeline_state.qpos
    # print("current-time", time)
    
    #so now on the dictionary grab a frame and see the duration and dt
    timestep_trajectory, dura_dt = env.dict_duration[k]
    if k >= 50:
        
        # print('time step', timestep_trajectory)
        # print('dura', dura_dt)
        # #only grab the right arm poses
        # tmp_pos = data_pos_mocap[k,right_shoulder_x:right_elbow+1]
        # updated = qpos.at[right_shoulder_x:right_elbow+1].set(tmp_pos
        tmp_pos = env.reference_trajectory_qpos[k]
        updated = qpos.at[:].set(tmp_pos[:])
        
        state = state.tree_replace({'pipeline_state.qpos': updated})
        ctrl = -0.1 * jp.ones(env.sys.nv)
    state = jit_step(state, ctrl)
    #print(state.pipeline_state.time)
    rollout.append(state.pipeline_state)
        
    #time += env.sys.dt
    time += dura_dt

# %%
visualizer(rollout)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
env.dict_duration
# Out:
# {0: [0.0, 0.0166660007],
#  1: [0.016666000708937645, 0.0166660007],
#  2: [0.03333200141787529, 0.0166660007],
#  3: [0.049998000264167786, 0.0166660007],
#  4: [0.06666400283575058, 0.0166660007],
#  5: [0.08333000540733337, 0.0166660007],
#  6: [0.09999600052833557, 0.0166660007],
#  7: [0.11666200309991837, 0.0166660007],
#  8: [0.13332800567150116, 0.0166660007],
#  9: [0.14999400079250336, 0.0166660007],
#  10: [0.16666001081466675, 0.0166660007],
#  11: [0.18332600593566895, 0.0166660007],
#  12: [0.19999200105667114, 0.0166660007],
#  13: [0.21665799617767334, 0.0166660007],
#  14: [0.23332400619983673, 0.0166660007],
#  15: [0.24999000132083893, 0.0166660007],
#  16: [0.2666560113430023, 0.0166660007],
#  17: [0.2833220064640045, 0.0166660007],
#  18: [0.2999880015850067, 0.0166660007],
#  19: [0.3166539967060089, 0.0166660007],
#  20: [0.3333200216293335, 0.0166660007],
#  21: [0.3499860167503357, 0.0166660007],
#  22: [0.3666520118713379, 0.0166660007],
#  23: [0.3833180069923401, 0.0166660007],
#  24: [0.3999840021133423, 0.0166660007],
#  25: [0.4166499972343445, 0.0166660007],
#  26: [0.4333159923553467, 0.0166660007],
#  27: [0.4499819874763489, 0.0166660007],
#  28: [0.46664801239967346, 0.0166660007],
#  29: [0.48331400752067566, 0.0166660007],
#  30: [0.49998000264167786, 0.0166660007],
#  31: [0.5166460275650024, 0.0166660007],
#  32: [0.5333120226860046, 0.0166660007],
#  33: [0.5499780178070068, 0.0166660007],
#  34: [0.566644012928009, 0.0166660007],
#  35: [0.5833100080490112, 0.0166660007],
#  36: [0.5999760031700134, 0.0166660007],
#  37: [0.6166419982910156, 0.0166660007],
#  38: [0.6333079934120178, 0.0166660007],
#  39: [0.64997398853302, 0.0166660007],
#  40: [0.666640043258667, 0.0166660007],
#  41: [0.6833060383796692, 0.0166660007],
#  42: [0.6999720335006714, 0.0166660007],
#  43: [0.7166380286216736, 0.0166660007],
#  44: [0.7333040237426758, 0.0166660007],
#  45: [0.749970018863678, 0.0166660007],
#  46: [0.7666360139846802, 0.0166660007],
#  47: [0.7833020091056824, 0.0166660007],
#  48: [0.7999680042266846, 0.0166660007],
#  49: [0.8166339993476868, 0.0166660007],
#  50: [0.833299994468689, 0.0166660007],
#  51: [0.8499659895896912, 0.0166660007],
#  52: [0.8666319847106934, 0.0166660007],
#  53: [0.8832979798316956, 0.0166660007],
#  54: [0.8999639749526978, 0.0166660007],
#  55: [0.9166299700737, 0.0166660007],
#  56: [0.9332960247993469, 0.0166660007],
#  57: [0.9499620199203491, 0.0166660007],
#  58: [0.9666280150413513, 0.0166660007],
#  59: [0.9832940101623535, 0.0166660007],
#  60: [0.9999600052833557, 0.0166660007],
#  61: [1.016626000404358, 0.0166660007],
#  62: [1.0332920551300049, 0.0166660007],
#  63: [1.0499581098556519, 0.0166660007],
#  64: [1.0666240453720093, 0.0166660007],
#  65: [1.0832901000976562, 0.0166660007],
#  66: [1.0999560356140137, 0.0166660007],
#  67: [1.1166220903396606, 0.0166660007],
#  68: [1.133288025856018, 0.0166660007],
#  69: [1.149954080581665, 0.0166660007],
#  70: [1.1666200160980225, 0.0166660007],
#  71: [1.1832860708236694, 0.0166660007],
#  72: [1.1999520063400269, 0.0166660007],
#  73: [1.2166180610656738, 0.0166660007],
#  74: [1.2332839965820312, 0.0166660007],
#  75: [1.2499500513076782, 0.0166660007],
#  76: [1.2666159868240356, 0.0166660007],
#  77: [1.2832820415496826, 0.0166660007],
#  78: [1.29994797706604, 0.0166660007],
#  79: [1.316614031791687, 0.0166660007],
#  80: [1.333280086517334, 0.0166660007],
#  81: [1.349946141242981, 0.0166660007],
#  82: [1.3666120767593384, 0.0166660007],
#  83: [1.3832781314849854, 0.0166660007],
#  84: [1.3999440670013428, 0.0166660007],
#  85: [1.4166101217269897, 0.0166660007],
#  86: [1.4332760572433472, 0.0166660007],
#  87: [1.4499421119689941, 0.0166660007],
#  88: [1.4666080474853516, 0.0166660007],
#  89: [1.4832741022109985, 0.0166660007],
#  90: [1.499940037727356, 0.0166660007],
#  91: [1.516606092453003, 0.0166660007],
#  92: [1.5332720279693604, 0.0166660007],
#  93: [1.5499380826950073, 0.0166660007],
#  94: [1.5666040182113647, 0.0166660007],
#  95: [1.5832700729370117, 0.0166660007],
#  96: [1.5999360084533691, 0.0166660007],
#  97: [1.6166020631790161, 0.0166660007],
#  98: [1.6332679986953735, 0.0166660007],
#  99: [1.6499340534210205, 0.0166660007],
#  100: [1.666599988937378, 0.0166660007],
#  101: [1.683266043663025, 0.0166660007],
#  102: [1.6999319791793823, 0.0166660007],
#  103: [1.7165980339050293, 0.0166660007],
#  104: [1.7332639694213867, 0.0166660007],
#  105: [1.7499300241470337, 0.0166660007],
#  106: [1.7665959596633911, 0.0166660007],
#  107: [1.783262014389038, 0.0166660007],
#  108: [1.7999279499053955, 0.0166660007],
#  109: [1.8165940046310425, 0.0166660007],
#  110: [1.8332599401474, 0.0166660007],
#  111: [1.8499259948730469, 0.0166660007],
#  112: [1.8665920495986938, 0.0166660007],
#  113: [1.8832581043243408, 0.0166660007],
#  114: [1.8999240398406982, 0.0166660007],
#  115: [1.9165900945663452, 0.0166660007],
#  116: [1.9332560300827026, 0.0166660007],
#  117: [1.9499220848083496, 0.0166660007],
#  118: [1.966588020324707, 0.0166660007],
#  119: [1.983254075050354, 0.0166660007],
#  120: [1.9999200105667114, 0.0166660007],
#  121: [2.0165860652923584, 0.0166660007],
#  122: [2.033252000808716, 0.0166660007],
#  123: [2.0499179363250732, 0.0166660007],
#  124: [2.0665841102600098, 0.0166660007],
#  125: [2.083250045776367, 0.0166660007],
#  126: [2.0999162197113037, 0.0166660007],
#  127: [2.116582155227661, 0.0166660007],
#  128: [2.1332480907440186, 0.0166660007],
#  129: [2.149914026260376, 0.0166660007],
#  130: [2.1665802001953125, 0.0166660007],
#  131: [2.18324613571167, 0.0166660007],
#  132: [2.1999120712280273, 0.0166660007],
#  133: [2.2165780067443848, 0.0166660007],
#  134: [2.2332441806793213, 0.0166660007],
#  135: [2.2499101161956787, 0.0166660007],
#  136: [2.266576051712036, 0.0166660007],
#  137: [2.2832419872283936, 0.0166660007],
#  138: [2.29990816116333, 0.0166660007],
#  139: [2.3165740966796875, 0.0166660007],
#  140: [2.333240032196045, 0.0166660007],
#  141: [2.3499059677124023, 0.0166660007],
#  142: [2.366572141647339, 0.0166660007],
#  143: [2.3832380771636963, 0.0166660007],
#  144: [2.3999040126800537, 0.0166660007],
#  145: [2.416569948196411, 0.0166660007],
#  146: [2.4332361221313477, 0.0166660007],
#  147: [2.449902057647705, 0.0166660007],
#  148: [2.4665679931640625, 0.0166660007],
#  149: [2.48323392868042, 0.0166660007],
#  150: [2.4999001026153564, 0.0166660007],
#  151: [2.516566038131714, 0.0166660007],
#  152: [2.5332319736480713, 0.0166660007],
#  153: [2.5498979091644287, 0.0166660007],
#  154: [2.5665640830993652, 0.0166660007],
#  155: [2.5832300186157227, 0.0166660007],
#  156: [2.59989595413208, 0.0166660007],
#  157: [2.6165618896484375, 0.0166660007],
#  158: [2.633228063583374, 0.0166660007],
#  159: [2.6498939990997314, 0.0166660007],
#  160: [2.666560173034668, 0.0166660007],
#  161: [2.6832261085510254, 0.0166660007],
#  162: [2.699892282485962, 0.0166660007],
#  163: [2.7165582180023193, 0.0166660007],
#  164: [2.7332241535186768, 0.0166660007],
#  165: [2.749890089035034, 0.0166660007],
#  166: [2.7665562629699707, 0.0166660007],
#  167: [2.783222198486328, 0.0166660007],
#  168: [2.7998881340026855, 0.0166660007],
#  169: [2.816554069519043, 0.0166660007],
#  170: [2.8332202434539795, 0.0166660007],
#  171: [2.849886178970337, 0.0166660007],
#  172: [2.8665521144866943, 0.0166660007],
#  173: [2.8832180500030518, 0.0166660007],
#  174: [2.8998842239379883, 0.0166660007],
#  175: [2.9165501594543457, 0.0166660007],
#  176: [2.933216094970703, 0.0166660007],
#  177: [2.9498820304870605, 0.0166660007],
#  178: [2.966548204421997, 0.0166660007],
#  179: [2.9832141399383545, 0.0166660007],
#  180: [2.999880075454712, 0.0166660007],
#  181: [3.0165460109710693, 0.0166660007],
#  182: [3.033212184906006, 0.0166660007],
#  183: [3.0498781204223633, 0.0166660007],
#  184: [3.0665440559387207, 0.0166660007],
#  185: [3.083209991455078, 0.0166660007],
#  186: [3.0998761653900146, 0.0166660007],
#  187: [3.116542100906372, 0.0166660007],
#  188: [3.1332080364227295, 0.0166660007],
#  189: [3.149873971939087, 0.0166660007],
#  190: [3.1665401458740234, 0.0166660007],
#  191: [3.183206081390381, 0.0166660007],
#  192: [3.1998720169067383, 0.0166660007],
#  193: [3.2165379524230957, 0.0166660007],
#  194: [3.2332041263580322, 0.0166660007],
#  195: [3.2498700618743896, 0.0166660007],
#  196: [3.266535997390747, 0.0166660007],
#  197: [3.2832019329071045, 0.0166660007],
#  198: [3.299868106842041, 0.0166660007],
#  199: [3.3165340423583984, 0.0166660007],
#  200: [3.333199977874756, 0.0166660007],
#  201: [3.3498659133911133, 0.0166660007],
#  202: [3.36653208732605, 0.0166660007],
#  203: [3.3831980228424072, 0.0166660007],
#  204: [3.3998639583587646, 0.0166660007],
#  205: [3.416529893875122, 0.0166660007],
#  206: [3.4331960678100586, 0.0166660007],
#  207: [3.449862003326416, 0.0166660007],
#  208: [3.4665279388427734, 0.0166660007],
#  209: [3.483193874359131, 0.0166660007],
#  210: [3.4998600482940674, 0.0166660007],
#  211: [3.516525983810425, 0.0166660007],
#  212: [3.5331919193267822, 0.0166660007],
#  213: [3.5498578548431396, 0.0166660007],
#  214: [3.566524028778076, 0.0166660007],
#  215: [3.5831899642944336, 0.0166660007],
#  216: [3.599855899810791, 0.0166660007],
#  217: [3.6165218353271484, 0.0166660007],
#  218: [3.633188009262085, 0.0166660007],
#  219: [3.6498539447784424, 0.0166660007],
#  220: [3.6665198802948, 0.0166660007],
#  221: [3.6831858158111572, 0.0166660007],
#  222: [3.6998519897460938, 0.0166660007],
#  223: [3.716517925262451, 0.0166660007],
#  224: [3.7331840991973877, 0.0166660007],
#  225: [3.749850034713745, 0.0166660007],
#  226: [3.7665162086486816, 0.0]}

# %%
def visualize_per_time_step():
    # initialize the state
    state = jit_reset(jax.random.PRNGKey(0))
    rollout = [state.pipeline_state]
    time = 0
    frames = 0
    N=3000
    for i in range(N):
        qpos = state.pipeline_state.qpos
        print("current-time", frames)
        
        frames = np.clip(frames,0,len(env.dict_duration)-1)
        
        print("current-time", type(frames))
        
        #so now on the dictionary grab a frame and see the duration and dt
        timestep_trajectory, dura_dt = env.dict_duration[frames]
        
        if time >= timestep_trajectory:
            #we increment the frames
            frames+=1
            
            # print('time step', timestep_trajectory)
            # print('dura', dura_dt)
        
            # print("frames:", frames)
            # #only grab the right arm poses
            # tmp_pos = data_pos_mocap[k,right_shoulder_x:right_elbow+1]
            # updated = qpos.at[right_shoulder_x:right_elbow+1].set(tmp_pos
            tmp_pos = env.reference_trajectory_qpos[frames]
            updated = qpos.at[:].set(tmp_pos[:])
            
            state = state.tree_replace({'pipeline_state.qpos': updated})
            ctrl = -0.1 * jp.ones(env.sys.nv)
            state = jit_step(state, ctrl)

                    #print(state.pipeline_state.time)
            rollout.append(state.pipeline_state)
            
        time += env.sys.dt
    return rollout

# %%
rollout = visualize_per_time_step()
visualizer(rollout)
# Out:
# current-time 0
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 1
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 2
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 3
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 4
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 5
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 6
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 7
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 8
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 9
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 10
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 11
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 12
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 13
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 14
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 15
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 16
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 17
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 18
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 19
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 20
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 21
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 22
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 23
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 24
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 25
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 26
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 27
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 28
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 29
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 30
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 31
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 32
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 33
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 34
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 35
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 36
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 37
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 38
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 39
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 40
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 41
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 42
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 43
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 44
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 45
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 46
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 47
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 48
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 49
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 50
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 51
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 52
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 53
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 54
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 55
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 56
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 57
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 58
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 59
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 60
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 61
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 62
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 63
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 64
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 65
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 66
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 67
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 68
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 69
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 70
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 71
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 72
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 73
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 74
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 75
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 76
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 77
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 78
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 79
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 80
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 81
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 82
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 83
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 84
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 85
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 86
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 87
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 88
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 89
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 90
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 91
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 92
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 93
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 94
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 95
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 96
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 97
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 98
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 99
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 100
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 101
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 102
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 103
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 104
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 105
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 106
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 107
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 108
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 109
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 110
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 111
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 112
# current-time <class 'numpy.int32'>
# current-time 113
# current-time <class 'numpy.int32'>
# current-time 113
# current-time <class 'numpy.int32'>
# current-time 113
# current-time <class 'numpy.int32'>
# current-time 113
# current-time <class 'numpy.int32'>
# current-time 113
# current-time <class 'numpy.int32'>
# current-time 113
# ...
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# current-time 227
# current-time <class 'numpy.int32'>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
env.duration_trajectory
# Out:
# 3.7665161581999853

# %% [markdown]
# Now I will test it with velocity

# %%
# initialize the state
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state.pipeline_state]

for k in range(len(env.dict_duration)):
    qpos = state.pipeline_state.qpos
    qvel = state.pipeline_state.qvel
    
    tmp_pos = env.reference_trajectory_qpos[k]
    tmp_vel = env.reference_trajectory_qvel[k]
    
    updated = qpos.at[:].set(tmp_pos[:])
    updated_vel = qvel.at[:].set(tmp_vel[:])
    
    state = state.tree_replace({'pipeline_state.qpos': updated})
    state = state.tree_replace({'pipeline_state.qvel': updated_vel})
    ctrl = -0.1 * jp.ones(env.sys.nv)
    state = jit_step(state, ctrl)
    #print(state.pipeline_state.time)
    rollout.append(state.pipeline_state)

# %%
visualizer(rollout)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
env.reference_trajectory_qvel.shape
# Out:
# (227, 34)

# %%
env.sys.dt
# Out:
# 0.002
