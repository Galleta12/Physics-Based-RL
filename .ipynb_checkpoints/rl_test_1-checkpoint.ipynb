# %%
import agents_env
from agents_env.agent_mimic_eval import HumanoidEnvTrainEval
from utils.SimpleConverter import SimpleConverter
from utils.util_data import *
from copy import deepcopy

# %%
from datetime import datetime
import functools
from IPython.display import HTML
import jax
from jax import numpy as jp
import numpy as np
from typing import Any, Dict, Sequence, Tuple, Union
from brax import base
from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.envs.base import Env, PipelineEnv, State
from brax.mjx.base import State as MjxState
from brax.training.agents.ppo import train as ppo
from brax.training.agents.ppo import networks as ppo_networks
from brax.io import html, mjcf, model
from etils import epath
from flax import struct
from matplotlib import pyplot as plt
import mediapy as media
from ml_collections import config_dict
import mujoco
from mujoco import mjx
from jax import vmap
import jax.random
from jax import lax

# %%
import distutils.util
import os
xla_flags = os.environ.get('XLA_FLAGS', '')
xla_flags += ' --xla_gpu_triton_gemm_any=True'
os.environ['XLA_FLAGS'] = xla_flags
print('Setting environment variable to use GPU rendering:')
# %env MUJOCO_GL=egl
# Out:
# Setting environment variable to use GPU rendering:
# env: MUJOCO_GL=egl

# %%
#since we are going to use custom trajectory, we will set up the initial
#and the end time
t_init = 1
t_end = 3

# %%
#this is just dummy data to initialize the agent
trajectory = SimpleConverter('motions/humanoid3d_punch.txt')
trajectory.load_mocap()
model_path = 'models/final_humanoid.xml'



data_pos_mocap = move_only_arm(jp.asarray(trajectory.data_pos))
data_vel_mocap =  move_only_arm_vel(jp.asarray(trajectory.data_vel))

data_dict_mocap = trajectory.duration_dict

data_xpos_mocap=jp.asarray(trajectory.data_xpos)
data_xrot_mocap=jp.asarray(trajectory.data_xrot)

# %%
#get th kp and kd for the agent
kp,kd = generate_kp_kd_gains()
print(kp)
print(kd)
# Out:
# [1000 1000 1000  100  100  100  400  400  400  300  400  400  400  300
#   500  500  500  500  400  400  400  500  500  500  500  400  400  400]
# [100 100 100  10  10  10  40  40  40  30  40  40  40  30  50  50  50  50
#   40  40  40  50  50  50  50  40  40  40]

# %%
envs.register_environment('humanoidEnvMimicEval',HumanoidEnvTrainEval )
env_name = 'humanoidEnvMimicEval'
env = envs.get_environment(env_name=env_name,
                           reference_trajectory_qpos=data_pos_mocap,
                           reference_trajectory_qvel = data_vel_mocap,
                            duration_trajectory=trajectory.total_time,
                            dict_duration= data_dict_mocap,
                           model_path=model_path,
                           kp_gains = kp,
                           kd_gains = kd,
                           reference_x_pos=data_xpos_mocap,
                           reference_x_rot=data_xrot_mocap)
jit_reset = jax.jit(env.reset)
jit_step = jax.jit(env.step)


#select the pd_control
from agents_env.pds_controllers_agents import stable_pd_controller_custom_trajectory, stable_pd_controller_trajectory,feedback_pd_controller
#env.set_pd_callback(stable_pd_controller_custom_trajectory)
env.set_pd_callback(feedback_pd_controller)

# %%
episode_len = env.rollout_lenght
print(episode_len)
# Out:
# 65

# %%
make_networks_factory = functools.partial(
    ppo_networks.make_ppo_networks,
        policy_hidden_layer_sizes=(512,256),
        value_hidden_layer_sizes =(512,256))
train_fn = functools.partial(
      ppo.train, num_timesteps=100_000_000, num_evals=1000+1,
      reward_scaling=1, episode_length=episode_len, normalize_observations=True,
      action_repeat=1, unroll_length=20, num_minibatches=32,
      num_updates_per_batch=4, discounting=0.95, learning_rate=0.0003,
      entropy_cost=1e-2, num_envs=8192, batch_size=256,
      network_factory=make_networks_factory,
      seed=0)




x_data = []
y_data = []
ydataerr = []
times = [datetime.now()]

max_y, min_y = 13000, 0
def progress(num_steps, metrics):
  times.append(datetime.now())
  x_data.append(num_steps)
  y_data.append(metrics['eval/episode_reward'])
  ydataerr.append(metrics['eval/episode_reward_std'])

  plt.xlim([0, train_fn.keywords['num_timesteps'] * 1.25])
  plt.ylim([min_y, max_y])

  plt.xlabel('# environment steps')
  plt.ylabel('reward per episode')
  plt.title(f'y={y_data[-1]:.3f}')

  plt.errorbar(
      x_data, y_data, yerr=ydataerr)
  plt.show()

make_inference_fn, params, _= train_fn(environment=env, progress_fn=progress)

print(f'time to jit: {times[1] - times[0]}')
print(f'time to train: {times[-1] - times[1]}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 40
#      36   plt.errorbar(
#      37       x_data, y_data, yerr=ydataerr)
#      38   plt.show()
# ---> 40 make_inference_fn, params, _= train_fn(environment=env, progress_fn=progress)
#      42 print(f'time to jit: {times[1] - times[0]}')
#      43 print(f'time to train: {times[-1] - times[1]}')
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/training/agents/ppo/train.py:226, in train(environment, num_timesteps, episode_length, action_repeat, num_envs, max_devices_per_host, num_eval_envs, learning_rate, entropy_cost, discounting, seed, unroll_length, batch_size, num_minibatches, num_updates_per_batch, num_evals, num_resets_per_eval, normalize_observations, reward_scaling, clipping_epsilon, gae_lambda, deterministic_eval, network_factory, progress_fn, normalize_advantage, eval_env, policy_params_fn, randomization_fn)
#     223 key_envs = jax.random.split(key_env, num_envs // process_count)
#     224 key_envs = jnp.reshape(key_envs,
#     225                        (local_devices_to_use, -1) + key_envs.shape[1:])
# --> 226 env_state = reset_fn(key_envs)
#     228 normalize = lambda x, y: x
#     229 if normalize_observations:
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:298, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     296 @api_boundary
#     297 def cache_miss(*args, **kwargs):
# --> 298   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     299       jit_info, *args, **kwargs)
#     300   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     301   maybe_fastpath_data = _get_fastpath_data(
#     302       executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     303       jit_info.abstracted_axes)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:176, in _python_pjit_helper(jit_info, *args, **kwargs)
#     173   args_flat = [*init_states, *args_flat]
#     175 try:
# --> 176   out_flat = pjit_p.bind(*args_flat, **params)
#     177 except pxla.DeviceAssignmentMismatchError as e:
#     178   fails, = e.args
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/core.py:2788, in AxisPrimitive.bind(self, *args, **params)
#    2784 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2785                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2786 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2787              else axis_main.with_cur_sublevel())
# -> 2788 return self.bind_with_trace(top_trace, args, params)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/core.py:425, in Primitive.bind_with_trace(self, trace, args, params)
#     424 def bind_with_trace(self, trace, args, params):
# --> 425   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     426   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:1488, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1485 has_explicit_sharding = _pjit_explicit_sharding(
#    1486     in_shardings, out_shardings, None, None)
#    1487 if xla_extension_version >= 226:
# -> 1488   return xc._xla.pjit(
#    1489       name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1490       tree_util.dispatch_registry,
#    1491       pxla.shard_arg if xla_extension_version >= 229 else pxla.temp_shard_arg,  # type: ignore
#    1492       _get_cpp_global_cache(has_explicit_sharding))(*args)
#    1493 else:
#    1494   return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,  # type: ignore
#    1495                       tree_util.dispatch_registry,
#    1496                       _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:1471, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1470 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1471   out_flat, compiled = _pjit_call_impl_python(
#    1472       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1473       out_shardings=out_shardings, resource_env=resource_env,
#    1474       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1475       inline=inline)
#    1476   fastpath_data = _get_fastpath_data(
#    1477       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1478       None)
#    1479   return out_flat, fastpath_data
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:1403, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1397 global _most_recent_pjit_call_executable
#    1399 in_shardings = _resolve_in_shardings(
#    1400     args, in_shardings, out_shardings,
#    1401     resource_env.physical_mesh if resource_env is not None else None)
# -> 1403 compiled = _pjit_lower(
#    1404     jaxpr, in_shardings, out_shardings, resource_env,
#    1405     donated_invars, name, keep_unused, inline,
#    1406     lowering_parameters=mlir.LoweringParameters()).compile()
#    1407 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1408 # This check is expensive so only do it if enable_checks is on.
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:1502, in _pjit_lower(*args, **kwargs)
#    1501 def _pjit_lower(*args, **kwargs):
# -> 1502   return _pjit_lower_cached(*args, **kwargs)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:1546, in _pjit_lower_cached(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, lowering_parameters, in_layouts, out_layouts)
#    1540   return pxla.lower_mesh_computation(
#    1541     jaxpr, api_name, name, mesh,
#    1542     in_shardings, out_shardings, donated_invars,
#    1543     True, jaxpr.in_avals, tiling_method=None,
#    1544     lowering_parameters=lowering_parameters)
#    1545 else:
# -> 1546   return pxla.lower_sharding_computation(
#    1547       jaxpr, api_name, name, in_shardings, out_shardings,
#    1548       tuple(donated_invars), tuple(jaxpr.in_avals),
#    1549       keep_unused=keep_unused, inline=inline,
#    1550       devices_from_context=(
#    1551           None if mesh is None or mesh.empty else list(mesh.devices.flat)),
#    1552       lowering_parameters=lowering_parameters, in_layouts=in_layouts,
#    1553       out_layouts=out_layouts)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2135, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, donated_invars, global_in_avals, keep_unused, inline, devices_from_context, lowering_parameters, in_layouts, out_layouts)
#    2130 semantic_out_shardings = SemanticallyEqualShardings(
#    2131     out_shardings, global_out_avals)  # type: ignore
#    2132 prim_requires_devices = dispatch.jaxpr_has_prim_requiring_devices(jaxpr)
#    2134 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2135  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2136      closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings,
#    2137      semantic_out_shardings, in_layouts, out_layouts, len(da_object),
#    2138      tuple(da_object) if prim_requires_devices else None, donated_invars,
#    2139      name_stack, all_default_mem_kind, inout_aliases,
#    2140      lowering_parameters=lowering_parameters)
#    2142 # backend and device_assignment is passed through to MeshExecutable because
#    2143 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2144 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2145 # because we calculate the device_assignment and backend before in_shardings,
#    2146 # etc are pruned.
#    2147 return MeshComputation(
#    2148     str(name_stack),
#    2149     module,
#    (...)
#    2171     all_default_mem_kind=all_default_mem_kind,
#    2172     all_args_info=all_args_info)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1941, in _cached_lowering_to_hlo(closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, name_stack, all_default_mem_kind, inout_aliases, lowering_parameters)
#    1936 ordered_effects = list(effects.ordered_effects.filter_in(closed_jaxpr.effects))
#    1938 with dispatch.log_elapsed_time(
#    1939       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time} sec",
#    1940       fun_name=str(name_stack), event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1941   lowering_result = mlir.lower_jaxpr_to_module(
#    1942       module_name,
#    1943       closed_jaxpr,
#    1944       ordered_effects=ordered_effects,
#    1945       backend_or_name=backend,
#    1946       # Optionally, override the lowering platform
#    1947       platforms=lowering_parameters.platforms or (backend.platform,),
#    1948       axis_context=axis_ctx,
#    1949       name_stack=name_stack,
#    1950       donated_args=donated_invars,
#    1951       replicated_args=replicated_args,
#    1952       arg_shardings=in_mlir_shardings,
#    1953       result_shardings=out_mlir_shardings,
#    1954       in_layouts=in_layouts,
#    1955       out_layouts=out_layouts,
#    1956       arg_names=jaxpr.debug_info and jaxpr.debug_info.arg_names,
#    1957       result_names=jaxpr.debug_info and jaxpr.debug_info.result_paths,
#    1958       num_replicas=nreps,
#    1959       num_partitions=num_partitions,
#    1960       all_default_mem_kind=all_default_mem_kind,
#    1961       input_output_aliases=inout_aliases,
#    1962       lowering_parameters=lowering_parameters)
#    1963 tuple_args = dispatch.should_tuple_args(len(global_in_avals), backend.platform)
#    1964 unordered_effects = list(
#    1965     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:969, in lower_jaxpr_to_module(***failed resolving arguments***)
#     967   attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
#     968   replace_tokens_with_dummy = lowering_parameters.replace_tokens_with_dummy
# --> 969   lower_jaxpr_to_fun(
#     970       ctx, "main", jaxpr, ordered_effects,
#     971       name_stack=name_stack,
#     972       public=True,
#     973       create_tokens=replace_tokens_with_dummy,
#     974       replace_tokens_with_dummy=replace_tokens_with_dummy,
#     975       num_output_tokens=0,
#     976       replicated_args=replicated_args,
#     977       arg_shardings=arg_shardings,
#     978       result_shardings=result_shardings,
#     979       input_output_aliases=input_output_aliases,
#     980       xla_donated_args=xla_donated_args,
#     981       arg_names=arg_names,
#     982       result_names=result_names,
#     983       arg_memory_kinds=arg_memory_kinds,
#     984       result_memory_kinds=result_memory_kinds,
#     985       arg_layouts=arg_layouts,
#     986       result_layouts=result_layouts)
#     988 try:
#     989   if not ctx.module.operation.verify():
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1431, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, num_output_tokens, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts)
#    1429 callee_name_stack = name_stack.extend(util.wrap_name(name, api_name))
#    1430 consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1431 out_vals, tokens_out = jaxpr_subcomp(
#    1432     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1433     consts, *args, dim_var_values=dim_var_values)
#    1434 outs = []
#    1435 if create_tokens:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1615, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1612   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    1614 rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1615 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1616                          platform_rules, default_rule,
#    1617                          eqn.effects,
#    1618                          *rule_inputs, **eqn.params)
#    1620 if effects:
#    1621   # If there were ordered effects in the primitive, there should be output
#    1622   # tokens we need for subsequent ordered effects.
#    1623   tokens_out = rule_ctx.tokens_out
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1723, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1721 # If there is a single rule left just apply the rule, without conditionals.
#    1722 if len(kept_rules) == 1:
# -> 1723  return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1725 assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#    1726 assert len(ctx.dim_var_values) >= 1, "Must have a platform_index variable"
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:1662, in _pjit_lowering(ctx, name, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, keep_unused, inline, *args)
#    1659 output_types = [mlir.token_type()] * len(effects) + output_types
#    1660 flat_output_types = flatten(output_types)
# -> 1662 func = _pjit_cached_lower_jaxpr_to_fun(
#    1663     ctx, name, jaxpr, tuple(effects), in_shardings,
#    1664     out_shardings, api_name=('jit' if resource_env is None else 'pjit'))
#    1666 tokens_in = [ctx.tokens_in.get(eff) for eff in effects]
#    1667 args = (*ctx.dim_var_values, *tokens_in, *args)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/pjit.py:1646, in _pjit_cached_lower_jaxpr_to_fun(ctx, name, jaxpr, effects, in_shardings, out_shardings, api_name)
#    1642   result_shardings = [None if is_unspecified(o) else o for o in out_shardings]
#    1643   # TODO(b/228598865): inlined calls cannot have shardings set directly on the
#    1644   # inputs or outputs because they are lost during MLIR->HLO conversion.
#    1645   # using_sharding_annotation=False means we add an identity operation instead.
# -> 1646   func = mlir.lower_jaxpr_to_fun(
#    1647       mod_ctx, name, jaxpr, effects, ctx.name_stack,
#    1648       arg_shardings=arg_shardings, result_shardings=result_shardings,
#    1649       use_sharding_annotations=False, api_name=api_name)
#    1650   mod_ctx.cached_primitive_lowerings[key] = func
#    1651 return func
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1431, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, num_output_tokens, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts)
#    1429 callee_name_stack = name_stack.extend(util.wrap_name(name, api_name))
#    1430 consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1431 out_vals, tokens_out = jaxpr_subcomp(
#    1432     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1433     consts, *args, dim_var_values=dim_var_values)
#    1434 outs = []
#    1435 if create_tokens:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1615, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1612   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    1614 rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1615 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1616                          platform_rules, default_rule,
#    1617                          eqn.effects,
#    1618                          *rule_inputs, **eqn.params)
#    1620 if effects:
#    1621   # If there were ordered effects in the primitive, there should be output
#    1622   # tokens we need for subsequent ordered effects.
#    1623   tokens_out = rule_ctx.tokens_out
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1723, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1721 # If there is a single rule left just apply the rule, without conditionals.
#    1722 if len(kept_rules) == 1:
# -> 1723  return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1725 assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#    1726 assert len(ctx.dim_var_values) >= 1, "Must have a platform_index variable"
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/lax/lax.py:3441, in _squeeze_lower(***failed resolving arguments***)
#    3439 def _squeeze_lower(ctx, operand, *, dimensions):
#    3440   del dimensions  # Implied by the output aval.
# -> 3441   return [mlir.reshape(ctx, operand, ctx.avals_out[0])]
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:1949, in reshape(ctx, op, aval_out)
#    1945   return hlo.dynamic_reshape(
#    1946       aval_to_ir_type(aval_out), op, shape,
#    1947   )
#    1948 else:
# -> 1949   return hlo.reshape(aval_to_ir_type(aval_out), op)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jaxlib/mlir/dialects/_stablehlo_ops_gen.py:4183, in reshape(result, operand, loc, ip)
#    4182 def reshape(result, operand, *, loc=None, ip=None) -> _ods_ir.Value:
# -> 4183   return _get_op_result_or_op_results(ReshapeOp(result=result, operand=operand, loc=loc, ip=ip))
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jaxlib/mlir/dialects/_stablehlo_ops_gen.py:4176, in ReshapeOp.__init__(self, result, operand, loc, ip)
#    4174 results.append(result)
#    4175 _ods_successors = None
# -> 4176 super().__init__(self.build_generic(attributes=attributes, results=results, operands=operands, successors=_ods_successors, regions=regions, loc=loc, ip=ip))
#
# KeyboardInterrupt:

# %%
import os

# Create a directory if it does not exist
os.makedirs('model_checkpoints', exist_ok=True)

# Save in the subdirectory
model_path = 'model_checkpoints/model_punch_policy'
model.save_params(model_path, params)
