# %%
from datetime import datetime
import functools
from IPython.display import HTML
import jax
from jax import numpy as jp
import numpy as np
from typing import Any, Dict, Sequence, Tuple, Union
from brax import base
from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.envs.base import Env, PipelineEnv, State
from brax.mjx.base import State as MjxState
from brax.training.agents.apg import train as apg
from brax.training.agents.apg import networks as apg_networks
from brax.io import html, mjcf, model
from etils import epath
from flax import struct
from matplotlib import pyplot as plt
import mediapy as media
from ml_collections import config_dict
import mujoco
from mujoco import mjx
from jax import vmap
import jax.random
from jax import lax

# %%
from utils.SimpleConverter import SimpleConverter
from agent_mimic_env.agent_template import HumanoidTemplate
from agent_mimic_env.agent_eval_template import HumanoidEvalTemplate
from utils.util_data import *
from copy import deepcopy

# %%
import agent_mimic_env
from agent_mimic_env import register_mimic_env

# %%
import distutils.util
import os
xla_flags = os.environ.get('XLA_FLAGS', '')
xla_flags += ' --xla_gpu_triton_gemm_any=True'
os.environ['XLA_FLAGS'] = xla_flags
print('Setting environment variable to use GPU rendering:')
# %env MUJOCO_GL=egl
# Out:
# Setting environment variable to use GPU rendering:
# env: MUJOCO_GL=egl

# %%
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# gpu

# %%
import yaml
from box import Box
# Path to your YAML file
yaml_file_path = 'config_params/punch.yaml'
# Load the YAML file
with open(yaml_file_path, 'r') as file:
    args = Box(yaml.safe_load(file))

# %%
from agent_mimic_env.pds_controllers_agents import feedback_pd_controller, stable_pd_controller_action

# %%
env_replay,env_eval=register_mimic_env(args)

#for the eval
jit_reset = jax.jit(env_eval.reset)
jit_step = jax.jit(env_eval.step)
env_eval.set_pd_callback(stable_pd_controller_action)

# %%
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state.pipeline_state]

# %%
from RLALG import agent_diffmimic as diff
from RLALG import agent_ppo as ppo
from RLALG import ppo_angent_networks as ppo_networks

# %%
make_networks_factory = functools.partial(
    ppo_networks.make_ppo_networks,
        policy_hidden_layer_sizes=(512,256),
        value_hidden_layer_sizes=(512,256))
make_networks_factory
# Out:
# functools.partial(<function make_ppo_networks at 0x7f4e4c17ade0>, policy_hidden_layer_sizes=(512, 256), value_hidden_layer_sizes=(512, 256))

# %%
episode_len = env_eval.rollout_lenght
print(episode_len)
# Out:
# 65

# %%
train_fn = functools.partial(
    ppo.train,
    num_timesteps=1000,  # Total timesteps for training
    #num_timesteps=100_000_000,  # Total timesteps for training
    num_evals=10,
    num_eval_envs=args.num_eval_envs,
    reward_scaling=1,
    episode_length=episode_len-1,  # Ensure episode_len is defined
    normalize_observations=args.normalize_observations,
    action_repeat=1,
    unroll_length=10,
    num_minibatches=24,  # Adjusted number of minibatches
    num_updates_per_batch=4,
    discounting=0.97,  # Discount factor γ
    learning_rate=3.0e-4,
    entropy_cost=1e-2,
    num_envs=256,  # Changed number of parallel environments to match batch size
    batch_size=256,  # Adjusted batch size
    network_factory=make_networks_factory,
    seed=0  # Random seed for reproducibility
)



x_data = []
y_data = []
ydataerr = []
y_pose_error = []  # to store pose error
times = [datetime.now()]
max_y_rewards, min_y_rewards = 0, -5
def progress(num_steps, metrics):
  
  #print(num_steps)
  times.append(datetime.now())
  x_data.append(num_steps)
  y_data.append(metrics['eval/episode_reward'])
  ydataerr.append(metrics['eval/episode_reward_std'])
  y_pose_error.append(metrics['eval/episode_pose_error'])  # capture pose error
  
  plt.figure(figsize=(10, 5))
  plt.subplot(1, 2, 1) 
  plt.xlim([0, num_steps* 1.25])
  plt.ylim([max_y_rewards, min_y_rewards])

  plt.xlabel('# environment steps')
  plt.ylabel('reward per episode')
  plt.title(f'Latest Reward: {y_data[-1]:.3f}')
  plt.plot(x_data, y_data, '-o')
  
  plt.subplot(1, 2, 2)
  plt.xlim([0, num_steps* 1.25])
  plt.ylim([min(y_pose_error) * 0.9, max(y_pose_error) * 1.1])
  plt.xlabel('# Environment Steps')
  plt.ylabel('Pose Error per Episode')
  plt.title(f'Latest Pose Error: {y_pose_error[-1]:.3f}')
  plt.plot(x_data, y_pose_error, '-o')
  

  plt.tight_layout()
  plt.show()
  
make_inference_fn, params, _= train_fn(environment=env_eval,
                                       progress_fn=progress,
                                       eval_env=env_eval)

print(f'time to jit: {times[1] - times[0]}')
print(f'time to train: {times[-1] - times[1]}')
# Out:
# episode lenght 65
# obs size 193
# act size 28
# /tmp/ipykernel_2389/643591347.py:32: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   plt.xlim([0, num_steps* 1.25])
# /tmp/ipykernel_2389/643591347.py:41: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   plt.xlim([0, num_steps* 1.25])
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/tornado/platform/asyncio.py:205, in start()
#     204 def start(self) -> None:
# --> 205     self.asyncio_loop.run_forever()
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/asyncio/base_events.py:608, in run_forever()
#     607 while True:
# --> 608     self._run_once()
#     609     if self._stopping:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/asyncio/base_events.py:1936, in _run_once()
#    1935     else:
# -> 1936         handle._run()
#    1937 handle = None
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/asyncio/events.py:84, in _run()
#      83 try:
# ---> 84     self._context.run(self._callback, *self._args)
#      85 except (SystemExit, KeyboardInterrupt):
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/kernelbase.py:545, in dispatch_queue()
#     544 try:
# --> 545     await self.process_one()
#     546 except Exception:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/kernelbase.py:534, in process_one()
#     533         return
# --> 534 await dispatch(*args)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/kernelbase.py:437, in dispatch_shell()
#     436     if inspect.isawaitable(result):
# --> 437         await result
#     438 except Exception:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/ipkernel.py:359, in execute_request()
#     358 self._associate_new_top_level_threads_with(parent_header)
# --> 359 await super().execute_request(stream, ident, parent)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/kernelbase.py:778, in execute_request()
#     777 if inspect.isawaitable(reply_content):
# --> 778     reply_content = await reply_content
#     780 # Flush output before sending the reply.
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/ipkernel.py:446, in do_execute()
#     445 if accepts_params["cell_id"]:
# --> 446     res = shell.run_cell(
#     447         code,
#     448         store_history=store_history,
#     449         silent=silent,
#     450         cell_id=cell_id,
#     451     )
#     452 else:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/ipykernel/zmqshell.py:549, in run_cell()
#     548 self._last_traceback = None
# --> 549 return super().run_cell(*args, **kwargs)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3075, in run_cell()
#    3074 try:
# -> 3075     result = self._run_cell(
#    3076         raw_cell, store_history, silent, shell_futures, cell_id
#    3077     )
#    3078 finally:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3130, in _run_cell()
#    3129 try:
# -> 3130     result = runner(coro)
#    3131 except BaseException as e:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner()
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3334, in run_cell_async()
#    3331 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3334 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3335        interactivity=interactivity, compiler=compiler, result=result)
#    3337 self.last_execution_succeeded = not has_raised
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3517, in run_ast_nodes()
#    3516     asy = compare(code)
# -> 3517 if await self.run_code(code, result, async_=asy):
#    3518     return True
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3577, in run_code()
#    3576     else:
# -> 3577         exec(code_obj, self.user_global_ns, self.user_ns)
#    3578 finally:
#    3579     # Reset our crash handler in place
#
# Cell In[25], line 52
#      50   plt.show()
# ---> 52 make_inference_fn, params, _= train_fn(environment=env_eval,
#      53                                        progress_fn=progress,
#      54                                        eval_env=env_eval)
#      56 print(f'time to jit: {times[1] - times[0]}')
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:311, in train()
#     309 epoch_keys = jax.random.split(epoch_key, local_devices_to_use)
#     310 (training_state,
# --> 311  training_metrics) = training_epoch_with_timing(training_state, epoch_keys)
#     313 if process_id == 0:
#     314   # Run evals.
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:226, in training_epoch_with_timing()
#     225 t = time.time()
# --> 226 (training_state, metrics) = training_epoch(training_state, key)
#     227 metrics = jax.tree_util.tree_map(jnp.mean, metrics)
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:194, in training_epoch()
#     193 key, key_grad = jax.random.split(key)
# --> 194 grad, (rewards, obs, metrics) = loss_grad(training_state.policy_params,
#     195                       training_state.normalizer_params, key_grad)
#     196 grad = clip_by_global_norm(grad)
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:179, in loss()
#     176 f = functools.partial(
#     177     env_step, policy=make_policy((normalizer_params, policy_params)))
#     178 (rewards,
# --> 179  obs, metrics) = jax.lax.scan(f, (env_state, key_scan),
#     180                      (jnp.array(range(episode_length // action_repeat))))[1]
#     181 return -jnp.mean(rewards), (rewards, obs, metrics)
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:164, in env_step()
#     163 actions = policy(env_state.obs, key_sample)[0]
# --> 164 nstate = env.step(env_state, actions)
#     165 if truncation_length is not None:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/envs/wrappers/training.py:122, in step()
#     121 state = state.replace(done=jp.zeros_like(state.done))
# --> 122 state = self.env.step(state, action)
#     124 def where_done(x, y):
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/envs/wrappers/training.py:71, in step()
#      70 def step(self, state: State, action: jax.Array) -> State:
# ---> 71   return jax.vmap(self.env.step)(state, action)
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/envs/wrappers/training.py:93, in step()
#      91   return nstate, nstate.reward
# ---> 93 state, rewards = jax.lax.scan(f, state, (), self.action_repeat)
#      94 state = state.replace(reward=jp.sum(rewards, axis=0))
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/envs/wrappers/training.py:90, in f()
#      89 def f(state, _):
# ---> 90   nstate = self.env.step(state, action)
#      91   return nstate, nstate.reward
#
# File ~/workspace/Physics-Based-RL/agent_mimic_env/agent_eval_template.py:82, in step()
#      79 torque = self.pd_function(action,self.sys,state,qpos,qvel,
#      80                          self.kp_gains,self.kd_gains,timeEnv,self.sys.dt)
# ---> 82 data = self.pipeline_step(state.pipeline_state,torque)
#      85 #get the observations
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/envs/base.py:130, in pipeline_step()
#     125   return (
#     126       self._pipeline.step(self.sys, state, action, self._debug),
#     127       None,
#     128   )
# --> 130 return jax.lax.scan(f, pipeline_state, (), self._n_frames)[0]
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/envs/base.py:126, in f()
#     124 def f(state, _):
#     125   return (
# --> 126       self._pipeline.step(self.sys, state, action, self._debug),
#     127       None,
#     128   )
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/brax/mjx/pipeline.py:91, in step()
#      90 data = state.replace(ctrl=act)
# ---> 91 data = mjx.step(sys, data)
#      93 q, qd = data.qpos, data.qvel
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/mujoco/mjx/_src/forward.py:56, in wrapper()
#      55 with jax.named_scope(name or getattr(fn, '__name__')):
# ---> 56   res = fn(*args, **kwargs)
#      57 return res
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/mujoco/mjx/_src/forward.py:365, in step()
#     364 """Advance simulation."""
# --> 365 d = forward(m, d)
#     367 if m.opt.integrator == IntegratorType.EULER:
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/mujoco/mjx/_src/forward.py:56, in wrapper()
#      55 with jax.named_scope(name or getattr(fn, '__name__')):
# ---> 56   res = fn(*args, **kwargs)
#      57 return res
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/mujoco/mjx/_src/forward.py:357, in forward()
#     355   return d
# --> 357 d = named_scope(solver.solve)(m, d)
#     359 return d
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/mujoco/mjx/_src/forward.py:56, in wrapper()
#      55 with jax.named_scope(name or getattr(fn, '__name__')):
# ---> 56   res = fn(*args, **kwargs)
#      57 return res
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/mujoco/mjx/_src/solver.py:363, in solve()
#     362 else:
# --> 363   ctx = jax.lax.while_loop(cond, body, ctx)
#     365 d = d.replace(
#     366     qacc_warmstart=ctx.qacc,
#     367     qacc=ctx.qacc,
#     368     qfrc_constraint=ctx.qfrc_constraint,
#     369     efc_force=ctx.efc_force,
#     370 )
#
# JaxStackTraceBeforeTransformation: ValueError: Reverse-mode differentiation does not work for lax.while_loop or lax.fori_loop with dynamic start/stop values. Try using lax.scan, or using fori_loop with static start/stop.
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 52
#      49   plt.tight_layout()
#      50   plt.show()
# ---> 52 make_inference_fn, params, _= train_fn(environment=env_eval,
#      53                                        progress_fn=progress,
#      54                                        eval_env=env_eval)
#      56 print(f'time to jit: {times[1] - times[0]}')
#      57 print(f'time to train: {times[-1] - times[1]}')
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:311, in train(environment, episode_length, action_repeat, num_envs, max_devices_per_host, num_eval_envs, learning_rate, seed, truncation_length, max_gradient_norm, num_evals, normalize_observations, deterministic_eval, network_factory, progress_fn, eval_env, eval_episode_length, use_linear_scheduler, randomization_fn)
#     308 epoch_key, local_key = jax.random.split(local_key)
#     309 epoch_keys = jax.random.split(epoch_key, local_devices_to_use)
#     310 (training_state,
# --> 311  training_metrics) = training_epoch_with_timing(training_state, epoch_keys)
#     313 if process_id == 0:
#     314   # Run evals.
#     315   metrics = evaluator.run_evaluation(
#     316       _unpmap(
#     317           (training_state.normalizer_params, training_state.policy_params)),
#     318       training_metrics)
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:226, in train.<locals>.training_epoch_with_timing(training_state, key)
#     224 nonlocal training_walltime
#     225 t = time.time()
# --> 226 (training_state, metrics) = training_epoch(training_state, key)
#     227 metrics = jax.tree_util.tree_map(jnp.mean, metrics)
#     228 jax.tree_util.tree_map(lambda x: x.block_until_ready(), metrics)
#
#     [... skipping hidden 12 frame]
#
# File ~/workspace/Physics-Based-RL/RLALG/agent_diffmimic.py:194, in train.<locals>.training_epoch(training_state, key)
#     192 def training_epoch(training_state: TrainingState, key: PRNGKey):
#     193   key, key_grad = jax.random.split(key)
# --> 194   grad, (rewards, obs, metrics) = loss_grad(training_state.policy_params,
#     195                         training_state.normalizer_params, key_grad)
#     196   grad = clip_by_global_norm(grad)
#     197   grad = jax.lax.pmean(grad, axis_name='i')
#
#     [... skipping hidden 36 frame]
#
# File ~/anaconda3/envs/jaxMujoco/lib/python3.11/site-packages/jax/_src/lax/control_flow/loops.py:1698, in _while_transpose_error(*_, **kwargs)
#    1697 def _while_transpose_error(*_, **kwargs):
# -> 1698   raise ValueError("Reverse-mode differentiation does not work for "
#    1699                    "lax.while_loop or lax.fori_loop with dynamic start/stop values. "
#    1700                    "Try using lax.scan, or using fori_loop with static start/stop.")
#
# ValueError: Reverse-mode differentiation does not work for lax.while_loop or lax.fori_loop with dynamic start/stop values. Try using lax.scan, or using fori_loop with static start/stop.
